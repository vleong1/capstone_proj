# %% [markdown]
# ## EDA & Data Visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in grouped cupid data
#cupid_religion = pd.read_pickle('data/cupid_religion.pkl')

cupid_df = pd.read_pickle('data/grouped_cupid.pkl')

# %%
cupid_df.head(3)
# Out:
#    age sex orientation body_type      diet     drinks      drugs  \
# 0   22   m    straight   average  anything  sometimes         no
# 1   35   m    straight   average     other        yes  sometimes
# 2   38   m    straight      thin  anything  sometimes         no
#
#                                offspring                 pets        religion  \
# 0  doesn't have kid(s), but wants kid(s)  likes dogs and cats     agnosticism
# 1  doesn't have kid(s), but wants kid(s)  likes dogs and cats  doesn't matter
# 2                      doesn't have kids           likes cats  doesn't matter
#
#       smokes
# 0  sometimes
# 1         no
# 2         no

# %% [markdown]
# ---

# %%
# count of age by sex

plt.figure(figsize = (20,8))
sns.set(font_scale = 1.5)
sns.countplot(x = 'age', data = cupid_df, hue = 'sex')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution by Sex');

# %%
plt.figure(figsize = (20,8))
sns.set(font_scale = 1)
sns.countplot(x = 'religion', data = cupid_df)
# Out:
# <AxesSubplot:xlabel='religion', ylabel='count'>

# %%
plt.figure(figsize = (8,6))
sns.set(font_scale = 1)
sns.countplot(x = 'orientation', data = cupid_df, hue = 'sex')
plt.xlabel('Orientation')
plt.ylabel('Count')
plt.title('Orientation by Sex');

# %%
plt.figure(figsize = (8,6))
sns.set(font_scale = 1)
sns.countplot(x = 'body_type', data = cupid_df[cupid_df['pets'] == 'likes dogs and cats'])
plt.xlabel('Body Type')
plt.ylabel('Count')
plt.title('Orientation by Sex');

# %%
plt.figure(figsize = (20,8))
sns.countplot(x = 'religion', data = cupid_df, hue = 'orientation')
# Out:
# <AxesSubplot:xlabel='religion', ylabel='count'>
